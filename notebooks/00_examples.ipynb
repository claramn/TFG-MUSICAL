# %%
N = 100

# %% [markdown]
# # Extract n examples from each model

# %% [markdown]
# ### Autoencoder

# %%
# Reconstruction:

def recons_AE(n, ogs):
    pass

def sample_AE(n):
    pass

# %% [markdown]
# ### VAE

# %%
def recons_VAE(n, ogs):
    pass

def sample_VAE(n):
    pass

# %% [markdown]
# ### Latent VAE

# %%
def latent_VAE(n):
    pass

# %% [markdown]
# ### cVAE

# %%
def recons_cVAE(n, ogs, instrumento_idx, pitch_norm, velocity_norm, brightness, sustain, stochastic=True):
    pass

def sample_cVAE(n, instrumento_idx, pitch_norm, velocity_norm, brightness, sustain, stochastic=True):
    pass

# %% [markdown]
# ### Latent cVAE

# %%
def latent_cVAE(n, instrumento_idx, pitch_norm, velocity_norm, brightness, sustain, stochastic=True):
    pass

# %% [markdown]
# ## Usage

# %%
def store_samples(samples, folder):
    pass

# %%
ogs, conds = [] # extraidos de NSynth


store_samples(ogs, "originals")

samples = recons_AE(N, ogs)
store_samples(samples, "recons_AE")
samples = sample_AE(N)
store_samples(samples, "sample_AE")
samples = recons_VAE(N, ogs)
store_samples(samples, "recons_VAE")
samples = sample_VAE(N)
store_samples(samples, "sample_VAE")

# CVAE es un caso especial
samples = recons_cVAE(N, ogs, conds...)
store_samples(samples, "recons_cVAE")
samples = sample_cVAE(N, conds...)
store_samples(samples, "sample_cVAE")
